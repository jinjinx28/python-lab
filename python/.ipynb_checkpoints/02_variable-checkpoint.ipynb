# %% [markdown]
# # 1. 변수란?

# %% [markdown]
# - 자료(데이터)를 넣을 수 있는 저장 공간
# - 변수명 : 변수를 넣은 공간에 붙인 이름
# - 형식 : 변수명 = 자료(데이터)

# %%
# a라는 변수에 10을 입력
a = 10
print ('a = ', a)
# Out:
# a =  10

# %%
b = 3
b
b = 100

# %%
b
# Out:
# 100

# %%
a + b
# Out:
# 110

# %%
a = 20
b = 30

# %% [markdown]
# a
# b
# a + b

# %%
print (a)
print (b)
a + b
# Out:
# 20
# 30
# 50

# %% [markdown]
# ## 반드시 지켜야 하는 규칙
# 1. 숫자로 시작하지 않는다
# 2. 공백이 포함되지 않는다
# 3. 기호가 포함되지 않는다
# 4. 예약어(키워드)는 사용하지 않는다

# %% [markdown]
# ## 변수에 이름을 붙이는 규칙

# %% [markdown]
# ### 💥에러 발생은 안되지만 참고해야할 사항
# - 대소문자 구분
# - 한 번에 여러 개 변수 선언 가능
# - 하나의 값을 여러 변수에 저장 가능

# %%
abc = 100
abc
# Out:
# 100

# %%
ABC = 100
ABC
# Out:
# 100

# %%
print (abc, ABC)
# Out:
# 100 100
